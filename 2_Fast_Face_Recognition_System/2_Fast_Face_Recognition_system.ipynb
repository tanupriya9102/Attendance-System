# %%
import os
import cv2
import numpy as np
import pandas as pd

from insightface.app import FaceAnalysis

# %%
# configure model
faceapp=FaceAnalysis(name='buffalo_sc',
                     root='insightface_model',
                     providers=['CPUExecutionProvider'])
faceapp.prepare(ctx_id=0,det_size=(640,640),det_thresh=0.5)
# don't set threshold below 0.3
# Out:
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: insightface_model\models\buffalo_sc\det_500m.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: insightface_model\models\buffalo_sc\w600k_mbf.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# set det-size: (640, 640)

# %% [markdown]
# # DATA PREPROCESSING

# %% [markdown]
# ## Extract Facial Features and labels

# %%
import re

# %%
def clean_name(string):
    string=string.title()
    string=re.sub(r'[^A-Za-z]',' ',string)
    return string

# %%
l=os.listdir(path='images')
person_info=[]
for f in l:
    role,name=f.split('-')
    name=clean_name(name)
    role=clean_name(role)
    print("Role=",role,end='\t')
    print("Name=",name)
    
    #path of each image in respective folder
    #name of img
    img_files=os.listdir(path=f'images/{f}')
    print(img_files)
#     path of img
    for file in img_files:
        path=f'./images/{f}/{file}'
#       step 1: read the image
        img_arr=cv2.imread(path)
#         step 2: get facial info
        result=faceapp.get(img_arr,max_num=1) #max_num is 1 cuz only 1face in to train
#        step 3: extract facial features 
        if len(result)>0:
            res=result[0]
            embedding=res['embedding']
#             step 4: save all info name,role,embedding in a list
            person_info.append([name,role,embedding])
# Out:
# Role= Student	Name= Angelina Jolie
# ['angelina-1.jpeg', 'angelina-10.jpeg', 'angelina-2.jpeg', 'angelina-3.jpeg', 'angelina-4.jpeg', 'angelina-5.jpeg', 'angelina-6.jpeg', 'angelina-7.jpeg', 'angelina-8.jpeg', 'angelina-9.jpeg']
# Role= Student	Name= Chris Evans
# ['evans_1.jpeg', 'evans_10.jpeg', 'evans_2.jpeg', 'evans_3.jpeg', 'evans_4.jpeg', 'evans_5.jpeg', 'evans_6.jpeg', 'evans_7.jpeg', 'evans_8.jpeg', 'evans_9.jpeg']
# Role= Student	Name= Scarlett Johansson
# ['scarlet_10.jpeg', 'scarlet_13.jpeg', 'scarlet_14.jpeg', 'scarlet_17.jpeg', 'scarlet_18.jpeg', 'scarlet_20.jpeg', 'scarlet_25.jpeg', 'scarlet_31.jpeg', 'scarlet_4.jpeg', 'scarlet_7.jpeg']
# Role= Teacher	Name= Barack Obama
# ['obama_1.jpeg', 'obama_10.jpeg', 'obama_2.jpeg', 'obama_3.jpeg', 'obama_4.jpeg', 'obama_5.jpeg', 'obama_6.jpeg', 'obama_7.jpeg', 'obama_8.jpeg', 'obama_9.jpeg']
# Role= Teacher	Name= Morgan Freeman
# ['freeman_1.jpeg', 'freeman_10.jpeg', 'freeman_2.jpeg', 'freeman_3.jpeg', 'freeman_4.jpeg', 'freeman_5.jpeg', 'freeman_6.jpeg', 'freeman_7.jpeg', 'freeman_8.jpeg', 'freeman_9.jpeg']

# %%
df=pd.DataFrame(person_info,columns=['Name','Role','Facial_Features'])
df #Store in redis after removing redundancy
# Out:
#                   Name     Role  \
# 0       Angelina Jolie  Student
# 1       Angelina Jolie  Student
# 2       Angelina Jolie  Student
# 3       Angelina Jolie  Student
# 4       Angelina Jolie  Student
# 5       Angelina Jolie  Student
# 6       Angelina Jolie  Student
# 7       Angelina Jolie  Student
# 8       Angelina Jolie  Student
# 9       Angelina Jolie  Student
# 10         Chris Evans  Student
# 11         Chris Evans  Student
# 12         Chris Evans  Student
# 13         Chris Evans  Student
# 14         Chris Evans  Student
# 15         Chris Evans  Student
# 16         Chris Evans  Student
# 17         Chris Evans  Student
# 18         Chris Evans  Student
# 19         Chris Evans  Student
# 20  Scarlett Johansson  Student
# 21  Scarlett Johansson  Student
# 22  Scarlett Johansson  Student
# 23  Scarlett Johansson  Student
# 24  Scarlett Johansson  Student
# 25  Scarlett Johansson  Student
# 26  Scarlett Johansson  Student
# 27  Scarlett Johansson  Student
# 28  Scarlett Johansson  Student
# 29  Scarlett Johansson  Student
# 30        Barack Obama  Teacher
# 31        Barack Obama  Teacher
# 32        Barack Obama  Teacher
# 33        Barack Obama  Teacher
# 34        Barack Obama  Teacher
# 35        Barack Obama  Teacher
# 36        Barack Obama  Teacher
# 37        Barack Obama  Teacher
# 38        Barack Obama  Teacher
# 39        Barack Obama  Teacher
# 40      Morgan Freeman  Teacher
# 41      Morgan Freeman  Teacher
# 42      Morgan Freeman  Teacher
# 43      Morgan Freeman  Teacher
# 44      Morgan Freeman  Teacher
# 45      Morgan Freeman  Teacher
# 46      Morgan Freeman  Teacher
# 47      Morgan Freeman  Teacher
# 48      Morgan Freeman  Teacher
# 49      Morgan Freeman  Teacher
#
#                                       Facial_Features
# 0   [-0.8410335, 1.6623635, -0.745449, -2.138221, ...
# 1   [0.09012404, -0.4169108, -0.37650695, 0.424011...
# 2   [0.86389506, 0.32952017, 0.05781859, -1.453824...
# 3   [1.6630238, 1.161926, -0.4108489, -2.6416948, ...
# 4   [0.864314, 0.9437618, 0.4265172, -1.1836909, -...
# 5   [0.40983105, 1.1813736, -0.9961994, -1.4018284...
# 6   [0.42182076, 2.0830736, 1.0647428, -2.273447, ...
# 7   [0.3949412, 0.84420955, -0.615458, -2.105093, ...
# 8   [1.0928565, 1.1707087, -0.2880756, -2.0103226,...
# 9   [-0.63545597, 1.7897248, 0.5982856, -3.550097,...
# 10  [1.8036056, -2.3007426, -1.5808954, -1.1026118...
# 11  [1.7493404, -2.120471, -0.15235159, -0.9059930...
# 12  [0.44954258, -1.6314547, -0.95116156, -1.54259...
# 13  [0.85883987, -1.1002166, -0.77001214, -1.49178...
# 14  [-1.1621715, -0.68589675, -0.43853605, -2.8765...
# 15  [0.35467726, -0.69755995, -0.3004976, -1.91148...
# 16  [1.3098732, -2.090489, -1.037829, -1.797128, 2...
# 17  [0.9707996, -1.7576605, -1.3096284, -1.0258203...
# 18  [0.59196013, -1.4145615, -0.6702813, -1.311277...
# 19  [0.27377757, -0.8834741, -0.56312096, -0.63476...
# 20  [0.15684888, -0.15252304, -1.1749347, 0.223224...
# 21  [0.9988017, -0.3464318, -1.6072202, -0.3437336...
# 22  [0.41819817, -1.2333512, -1.1655853, 0.3192767...
# 23  [0.74071056, -0.2172078, -2.1699548, -0.382094...
# 24  [-0.2931065, -0.027625293, -3.0639057, -0.0226...
# 25  [0.9100211, -0.7951274, -2.354409, 0.8837526, ...
# 26  [0.5179118, -0.70606494, -1.5367962, 0.9526467...
# 27  [-0.97057724, -0.09699072, -2.1180046, 1.34241...
# 28  [0.87918776, -0.58773625, 0.08178866, 0.654351...
# 29  [-1.4453042, -0.7219956, -1.7936003, 0.79554, ...
# 30  [0.8677803, -0.26745942, 0.07078171, -0.144091...
# 31  [1.6958617, -0.99367774, -0.22316897, -1.74935...
# 32  [0.048864223, -0.49350148, -0.19512153, -1.123...
# 33  [0.7236616, -0.9442341, -0.08801663, -2.404883...
# 34  [0.59006596, 0.43526185, 0.35919923, -2.804093...
# 35  [0.32973936, -1.2769604, 0.40178412, -1.358962...
# 36  [-0.065288104, 0.015072167, -0.85322857, -0.32...
# 37  [2.2780032, -1.3971311, 1.5631793, -1.4795663,...
# 38  [1.6047919, -0.24347691, 0.36099565, 0.0407241...
# 39  [1.4112138, -0.41757023, -0.4472475, -1.443501...
# 40  [0.5251215, -0.52591586, -0.5172633, 0.82646, ...
# 41  [0.7933403, -0.4821412, -1.7259965, 0.6513129,...
# 42  [-0.1321992, 0.041241705, 0.62798566, 0.683336...
# 43  [0.4863371, -0.47723857, -1.0034816, 1.2772816...
# 44  [1.2949812, -0.9476242, -0.13746858, 1.0461172...
# 45  [-0.27421805, -0.27516162, -0.841787, 1.279445...
# 46  [0.7715305, -0.6374655, 0.17158228, 0.55102235...
# 47  [1.2277228, -1.564395, 0.4300081, 0.97241783, ...
# 48  [-0.26069024, 0.020205945, -0.41906506, 1.6750...
# 49  [0.42433766, -1.3480741, -0.6571427, 1.7235192...

# %% [markdown]
# # Step1: Read Image

# %%
# Load the image
img_test = cv2.imread('test_images/test_3.jpg')

cv2.imshow('test image', img_test)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Step2: Extract Features

# %%
res_test=faceapp.get(img_test,max_num=0)
for i,rt in enumerate(res_test):
#     print(i)
    bbox=rt['bbox'].astype(int)
    score=int(rt['det_score']*100)
    embed_test=rt['embedding']

# %%
# consider only 1 sample
len(embed_test)
# Out:
# 512

# %%
df.head()
# Out:
#              Name     Role                                    Facial_Features
# 0  Angelina Jolie  Student  [-0.8410335, 1.6623635, -0.745449, -2.138221, ...
# 1  Angelina Jolie  Student  [0.09012404, -0.4169108, -0.37650695, 0.424011...
# 2  Angelina Jolie  Student  [0.86389506, 0.32952017, 0.05781859, -1.453824...
# 3  Angelina Jolie  Student  [1.6630238, 1.161926, -0.4108489, -2.6416948, ...
# 4  Angelina Jolie  Student  [0.864314, 0.9437618, 0.4265172, -1.1836909, -...

# %%
X_list=df['Facial_Features'].tolist()
X=np.asarray(X_list)
X.shape
# Out:
# (50, 512)

# %%
from sklearn.metrics import pairwise

# %%
y=embed_test.reshape(1,-1) #1x512
euclidean_distance=pairwise.euclidean_distances(X,y)
manhattan_distance=pairwise.manhattan_distances(X,y)
cosine_similar=pairwise.cosine_similarity(X,y)

# %%
data_search=df.copy()
data_search['euclidean']=euclidean_distance
data_search['manhattan']=manhattan_distance
data_search['cosine']=cosine_similar

# %%
data_search
# Out:
#                   Name     Role  \
# 0       Angelina Jolie  Student
# 1       Angelina Jolie  Student
# 2       Angelina Jolie  Student
# 3       Angelina Jolie  Student
# 4       Angelina Jolie  Student
# 5       Angelina Jolie  Student
# 6       Angelina Jolie  Student
# 7       Angelina Jolie  Student
# 8       Angelina Jolie  Student
# 9       Angelina Jolie  Student
# 10         Chris Evans  Student
# 11         Chris Evans  Student
# 12         Chris Evans  Student
# 13         Chris Evans  Student
# 14         Chris Evans  Student
# 15         Chris Evans  Student
# 16         Chris Evans  Student
# 17         Chris Evans  Student
# 18         Chris Evans  Student
# 19         Chris Evans  Student
# 20  Scarlett Johansson  Student
# 21  Scarlett Johansson  Student
# 22  Scarlett Johansson  Student
# 23  Scarlett Johansson  Student
# 24  Scarlett Johansson  Student
# 25  Scarlett Johansson  Student
# 26  Scarlett Johansson  Student
# 27  Scarlett Johansson  Student
# 28  Scarlett Johansson  Student
# 29  Scarlett Johansson  Student
# 30        Barack Obama  Teacher
# 31        Barack Obama  Teacher
# 32        Barack Obama  Teacher
# 33        Barack Obama  Teacher
# 34        Barack Obama  Teacher
# 35        Barack Obama  Teacher
# 36        Barack Obama  Teacher
# 37        Barack Obama  Teacher
# 38        Barack Obama  Teacher
# 39        Barack Obama  Teacher
# 40      Morgan Freeman  Teacher
# 41      Morgan Freeman  Teacher
# 42      Morgan Freeman  Teacher
# 43      Morgan Freeman  Teacher
# 44      Morgan Freeman  Teacher
# 45      Morgan Freeman  Teacher
# 46      Morgan Freeman  Teacher
# 47      Morgan Freeman  Teacher
# 48      Morgan Freeman  Teacher
# 49      Morgan Freeman  Teacher
#
#                                       Facial_Features  euclidean   manhattan  \
# 0   [-0.8410335, 1.6623635, -0.745449, -2.138221, ...  35.328033  643.420105
# 1   [0.09012404, -0.4169108, -0.37650695, 0.424011...  32.449764  584.148831
# 2   [0.86389506, 0.32952017, 0.05781859, -1.453824...  37.117546  679.417400
# 3   [1.6630238, 1.161926, -0.4108489, -2.6416948, ...  36.873985  672.385460
# 4   [0.864314, 0.9437618, 0.4265172, -1.1836909, -...  34.319042  625.331543
# 5   [0.40983105, 1.1813736, -0.9961994, -1.4018284...  34.673912  637.396951
# 6   [0.42182076, 2.0830736, 1.0647428, -2.273447, ...  35.434174  651.596312
# 7   [0.3949412, 0.84420955, -0.615458, -2.105093, ...  35.748096  651.375726
# 8   [1.0928565, 1.1707087, -0.2880756, -2.0103226,...  33.760391  622.294044
# 9   [-0.63545597, 1.7897248, 0.5982856, -3.550097,...  37.442749  682.246667
# 10  [1.8036056, -2.3007426, -1.5808954, -1.1026118...  37.849213  678.750848
# 11  [1.7493404, -2.120471, -0.15235159, -0.9059930...  37.991726  683.852133
# 12  [0.44954258, -1.6314547, -0.95116156, -1.54259...  37.225407  681.389010
# 13  [0.85883987, -1.1002166, -0.77001214, -1.49178...  37.301586  677.700205
# 14  [-1.1621715, -0.68589675, -0.43853605, -2.8765...  34.088417  607.210052
# 15  [0.35467726, -0.69755995, -0.3004976, -1.91148...  35.641808  651.668779
# 16  [1.3098732, -2.090489, -1.037829, -1.797128, 2...  36.001099  659.330237
# 17  [0.9707996, -1.7576605, -1.3096284, -1.0258203...  34.691479  628.346793
# 18  [0.59196013, -1.4145615, -0.6702813, -1.311277...  35.329903  632.840128
# 19  [0.27377757, -0.8834741, -0.56312096, -0.63476...  36.035912  666.969704
# 20  [0.15684888, -0.15252304, -1.1749347, 0.223224...  18.872494  329.913499
# 21  [0.9988017, -0.3464318, -1.6072202, -0.3437336...  20.994419  376.273663
# 22  [0.41819817, -1.2333512, -1.1655853, 0.3192767...  19.246262  337.445122
# 23  [0.74071056, -0.2172078, -2.1699548, -0.382094...  21.683872  391.648487
# 24  [-0.2931065, -0.027625293, -3.0639057, -0.0226...  20.010487  356.554965
# 25  [0.9100211, -0.7951274, -2.354409, 0.8837526, ...  18.425682  331.417541
# 26  [0.5179118, -0.70606494, -1.5367962, 0.9526467...  22.201698  400.143882
# 27  [-0.97057724, -0.09699072, -2.1180046, 1.34241...  19.143875  342.204666
# 28  [0.87918776, -0.58773625, 0.08178866, 0.654351...  21.456215  385.317746
# 29  [-1.4453042, -0.7219956, -1.7936003, 0.79554, ...  19.419188  355.943036
# 30  [0.8677803, -0.26745942, 0.07078171, -0.144091...  36.514748  656.283314
# 31  [1.6958617, -0.99367774, -0.22316897, -1.74935...  34.796833  633.219222
# 32  [0.048864223, -0.49350148, -0.19512153, -1.123...  36.074734  656.151452
# 33  [0.7236616, -0.9442341, -0.08801663, -2.404883...  37.917671  694.277253
# 34  [0.59006596, 0.43526185, 0.35919923, -2.804093...  37.025787  675.819695
# 35  [0.32973936, -1.2769604, 0.40178412, -1.358962...  36.832298  661.808263
# 36  [-0.065288104, 0.015072167, -0.85322857, -0.32...  37.630520  671.359182
# 37  [2.2780032, -1.3971311, 1.5631793, -1.4795663,...  36.241932  662.566717
# 38  [1.6047919, -0.24347691, 0.36099565, 0.0407241...  35.642796  643.187767
# 39  [1.4112138, -0.41757023, -0.4472475, -1.443501...  37.608559  683.125844
# 40  [0.5251215, -0.52591586, -0.5172633, 0.82646, ...  35.647366  643.029644
# 41  [0.7933403, -0.4821412, -1.7259965, 0.6513129,...  37.331306  661.847962
# 42  [-0.1321992, 0.041241705, 0.62798566, 0.683336...  37.951447  680.300948
# 43  [0.4863371, -0.47723857, -1.0034816, 1.2772816...  37.352520  675.517554
# 44  [1.2949812, -0.9476242, -0.13746858, 1.0461172...  35.826572  647.046366
# 45  [-0.27421805, -0.27516162, -0.841787, 1.279445...  37.543434  678.025039
# 46  [0.7715305, -0.6374655, 0.17158228, 0.55102235...  36.692234  660.462505
# 47  [1.2277228, -1.564395, 0.4300081, 0.97241783, ...  36.591896  667.436917
# 48  [-0.26069024, 0.020205945, -0.41906506, 1.6750...  37.793598  675.513911
# 49  [0.42433766, -1.3480741, -0.6571427, 1.7235192...  38.673405  696.578875
#
#       cosine
# 0  -0.044062
# 1   0.135127
# 2  -0.104925
# 3  -0.043783
# 4   0.064824
# 5   0.019770
# 6  -0.047930
# 7  -0.056647
# 8   0.092580
# 9  -0.045580
# 10 -0.087335
# 11 -0.054062
# 12 -0.046866
# 13 -0.063920
# 14  0.049388
# 15 -0.004405
# 16 -0.037268
# 17 -0.012765
# 18 -0.006242
# 19 -0.092401
# 20  0.731325
# 21  0.663559
# 22  0.731990
# 23  0.647056
# 24  0.714680
# 25  0.762974
# 26  0.599273
# 27  0.736652
# 28  0.617932
# 29  0.713054
# 30  0.061816
# 31 -0.001042
# 32  0.022703
# 33  0.009386
# 34 -0.002328
# 35  0.041025
# 36  0.077534
# 37  0.040713
# 38  0.128251
# 39  0.002446
# 40  0.040304
# 41  0.018010
# 42  0.004798
# 43  0.033909
# 44  0.038181
# 45  0.032990
# 46  0.050226
# 47  0.064224
# 48  0.042929
# 49 -0.001670

# %% [markdown]
# # Identify person using Cosine Similarity

# %%
s_opt=0.5

# %%
datafilter=data_search.query(f'cosine>{s_opt}')
datafilter.reset_index(drop=True,inplace=True)
if len(datafilter)>0:
    argmax=datafilter['cosine'].argmax()
    name_cos,role_cos=datafilter.loc[argmax][['Name','Role']]
else:
    name_cos='Unknown'
    role_cos='Unknown'

# %%
print(name_cos,role_cos)
# Out:
# Scarlett Johansson Student

# %%
datafilter
# Out:
#                  Name     Role  \
# 0  Scarlett Johansson  Student
# 1  Scarlett Johansson  Student
# 2  Scarlett Johansson  Student
# 3  Scarlett Johansson  Student
# 4  Scarlett Johansson  Student
# 5  Scarlett Johansson  Student
# 6  Scarlett Johansson  Student
# 7  Scarlett Johansson  Student
# 8  Scarlett Johansson  Student
# 9  Scarlett Johansson  Student
#
#                                      Facial_Features  euclidean   manhattan  \
# 0  [0.15684888, -0.15252304, -1.1749347, 0.223224...  18.872494  329.913499
# 1  [0.9988017, -0.3464318, -1.6072202, -0.3437336...  20.994419  376.273663
# 2  [0.41819817, -1.2333512, -1.1655853, 0.3192767...  19.246262  337.445122
# 3  [0.74071056, -0.2172078, -2.1699548, -0.382094...  21.683872  391.648487
# 4  [-0.2931065, -0.027625293, -3.0639057, -0.0226...  20.010487  356.554965
# 5  [0.9100211, -0.7951274, -2.354409, 0.8837526, ...  18.425682  331.417541
# 6  [0.5179118, -0.70606494, -1.5367962, 0.9526467...  22.201698  400.143882
# 7  [-0.97057724, -0.09699072, -2.1180046, 1.34241...  19.143875  342.204666
# 8  [0.87918776, -0.58773625, 0.08178866, 0.654351...  21.456215  385.317746
# 9  [-1.4453042, -0.7219956, -1.7936003, 0.79554, ...  19.419188  355.943036
#
#      cosine
# 0  0.731325
# 1  0.663559
# 2  0.731990
# 3  0.647056
# 4  0.714680
# 5  0.762974
# 6  0.599273
# 7  0.736652
# 8  0.617932
# 9  0.713054

# %% [markdown]
# # Multiple People prediction

# %%
#     cosine similarity
def search_algo(df,feature_column,test_vector,name_role=['Name','Role'],thresh=0.5):
    df=df.copy()
    X_list=df[feature_column].tolist()
    x=np.asarray(X_list)
    
    similar=pairwise.cosine_similarity(x,test_vector.reshape(1,-1))
    similar_arr=np.array(similar).flatten()
    df['cosine']=similar_arr
    
    data_filter=df.query(f'cosine>{thresh}')
#    
    if len(data_filter)>0:
        data_filter.reset_index(drop=True,inplace=True)
        argmax=data_filter['cosine'].argmax()
        person_name,person_role=data_filter.loc[argmax][name_role]
        
    else:
        person_name=person_role='Unknown'
        
    return person_name,person_role

# %%
test_image=cv2.imread('test_images/test_2.jpg')
cv2.imshow('test image',test_image)
cv2.waitKey()
cv2.destroyAllWindows()
# test_image

# %%
results=faceapp.get(test_image)
test_copy=test_image.copy()
for res in results:
    x1,y1,x2,y2= res['bbox'].astype(int)
    embeddings=res['embedding']
    person_name,person_role=search_algo(df,'Facial_Features',test_vector=embeddings,name_role=['Name','Role'],thresh=0.5)
#     print(person_name,person_role)
    if person_name=="Unknown":
        color=(0,0,255) #bgr
    else:
        color=(0,255,0)
    
    cv2.rectangle(test_copy,(x1,y1),(x2,y2),color)
    text_gen=person_name
    cv2.putText(test_copy,text_gen,(x1,y1),cv2.FONT_HERSHEY_DUPLEX,0.6,color,2)
    

cv2.imshow('test image',test_copy)
cv2.waitKey()
cv2.destroyAllWindows()
